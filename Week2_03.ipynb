# %% [markdown]
# <a href="https://colab.research.google.com/github/Afqufai/Afqufai/blob/main/Week2_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Koneksi Google Drive dengan Colab

# %%
# Sinkronisasi
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Upload FIles
import cv2
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ef084999-e45f-48de-a95c-e936e448ff01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef084999-e45f-48de-a95c-e936e448ff01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab.patches import  cv2_imshow

img = cv2.imread('KTM lama.jpg')
cv2_imshow(img)
print('Resolusi Gambar: ', img.shape[1], ' x ', img.shape[0])
# Out:
# <PIL.Image.Image image mode=RGB size=800x500>
# Resolusi Gambar:  800  x  500

# %% [markdown]
# # Penampilan Gambar
# Impor gambar dari drive, lalu tampilkan gambar BGR nya

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/drive/MyDrive/Dataset/PCVK/KTM lama.jpg')
plt.imshow(img)

# %% [markdown]
# ## Ubah ke RGB, lalu tampilkan

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
# Alternatif Penampilan
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Tampilkan gambar dalam Grayscale

# %%
img_gray = cv2.imread('/content/drive/MyDrive/Dataset/PCVK/KTM lama.jpg', cv2.IMREAD_GRAYSCALE)

# Tanpa CMAP
plt.subplot(1,2,1)
plt.imshow(img_gray)
plt.title('Tanpa Cmap')

# Dengan CMAP
plt.subplot(1,2,2)
plt.imshow(img_gray, cmap='gray')
plt.title('Dengan Cmap')

plt.show()

# %% [markdown]
# Warna Lain, contohnya Magma

# %%
plt.imshow(img_gray, cmap='magma')
plt.show()

# %% [markdown]
# Melakukan Risizing

# %%
img = cv2.imread('/content/drive/MyDrive/Dataset/PCVK/KTM lama.jpg')
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgRGBsmall = cv2.resize(imgRGB, (400, 250))
plt.imshow(imgRGBsmall)
plt.show()

# %% [markdown]
# ## Flipping Gambar

# %%
imgBalik = cv2.flip(imgRGB, 1)
plt.imshow(imgBalik)

# %% [markdown]
# Gambar terbalik dengan ukuran kanvas yang lebih besar

# %%
imgBalik = cv2.flip(imgRGB, 1)

# Ukuran Kanvas
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(imgBalik)

# %% [markdown]
# # Bentuk Geometri 2D

# %%
# Import NP
import numpy as np

black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
# Beri persegi panjang di kanan atas
cv2.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
# Persegi Biru di Tengah
cv2.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
# Lingkaran Merah
cv2.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
# Penambahan lingkaran biru di sisi lain dengan thickness -1 (Fill)
cv2.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(black_img)

# %%
# Garis Pembatas
cv2.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
# Pemberian Teks
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv2.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# ## Menggambar 'Layangan'

# %%
# Reset Gambar
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img2)

# %%
# Buat titik-titik
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv2.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)
